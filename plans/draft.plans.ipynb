# %%
import json

f = open("../shopping link/shopping links.json")
shopping_list = json.load(f)

# %%
shopping_list
# Out:
# {'Food processor': {'David Jones': {'url': 'https://www.davidjones.com/product/kitchenaid-kfc3516aob-mini-35-cup-food-chopper-22070140',
#    'price class': 'css-1ps1gwj'},
#   'The Good Guys': {'url': 'https://www.thegoodguys.com.au/kitchenaid-mini-35-cup-chopper-empire-red-5kfc3516aer?cq_src=google_ads&cq_cmp=20562875486&cq_con=&cq_term=&cq_med=pla&cq_plac=&cq_net=x&cq_pos=&cq_plt=gp&cq_loci=&cq_locp=9071337&cq_mtype=&cq_dvic=c&cq_dvicm=&cq_trg=&cq_pdid=5KFC3516AER&gad_source=4&gclid=Cj0KCQjwtJ6_BhDWARIsAGanmKfoWkrLG2OOfIIMBMgxe7kGhWQa5k-QFj82jH6vG8B6-20M3QhaKc4aAn4TEALw_wcB&gclsrc=aw.ds',
#    'price class': 'curr'},
#   'Qantas Marketplace': {'url': 'https://marketplace.qantas.com/au/search/kitchen%20aid%20mini%20food%20chopper?terms=kitchen%20aid%20mini%20food%20chopper',
#    'price class': 'sc-entYTK jolZjk'},
#   'Myer': {'url': 'https://www.myer.com.au/p/kitchenaid-35-cup-mini-food-chopper-in-pistachio-5kfc3516apt',
#    'price class': 'css-1ps1gwj'}},
# ...

# %%
import requests 
from bs4 import BeautifulSoup

# %%
# get the inspect element part from the website 
response = requests.get(shopping_list['Shark CarpetXpert']['David Jones']['url'])

# %%
# above 
response.content
# Out:
# b'<!DOCTYPE HTML><html itemscope="itemscope" itemtype="http://schema.org/WebPage" xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml"><head><title xmlns:security="urn:security">Shark Ex200 Carpetxpert W Stainstriker Upright Deep Carpet Cleaner | David Jones</title><meta charset="UTF-8" xmlns:security="urn:security" /><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"76edb6ea42","applicationID":"138106663","transactionName":"YFRbMBQADRIEVBFaV1keeDc2TldRURkEQEhP","queueTime":0,"applicationTime":170,"agent":"","atts":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VQ8GWVdRChABV1lTBwcBUFc=",licenseKey:"76edb6ea42",applicationID:"138106663"};;/*! For license information please see nr-loader-full-1.285.0.min.js.LICENSE.txt */\n(
# ...

# %%
# beautiful soup has knowledge of html - more structure. Returns output 
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML>
# <html itemscope="itemscope" itemtype="http://schema.org/WebPage" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#"><head><title xmlns:security="urn:security">Shark Ex200 Carpetxpert W Stainstriker Upright Deep Carpet Cleaner | David Jones</title><meta charset="utf-8" xmlns:security="urn:security"/><script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"76edb6ea42","applicationID":"138106663","transactionName":"YFRbMBQADRIEVBFaV1keeDc2TldRURkEQEhP","queueTime":0,"applicationTime":170,"agent":"","atts":""}</script><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VQ8GWVdRChABV1lTBwcBUFc=",licenseKey:"76edb6ea42",applicationID:"138106663"};;/*! For license information please see nr-loader-full-1.285.0.min.js.LICENSE.txt */
# ...

# %%
# find price class from david jones website should output the price - DOESNT WORK FOR DAVID JONES

#price_element = soup.find('span', class_=shopping_list['Shark CarpetXpert']['David Jones']['price class'])
#price_element
# Out:
# <span class="price-display" data-currency-format="$">
# 																							{{previous_price_au}}
# 																						</span>

# %%
# price for david jones 
price_element = soup.findAll('span', 
                             class_=shopping_list['Shark CarpetXpert']['David Jones']['price class'],
                             attrs= shopping_list['Shark CarpetXpert']['David Jones']['search attr'])

# %%
price_element
# Out:
# [<span class="price-display" content="438.00" itemprop="price">$438.00</span>]

# %%
# <> is the html code thing so .text is the text inside the html code
price_element[0]['content']
# price_element[0].text gives you the same output
# Out:
# '438.00'
